# %%
! pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.26.3-py3-none-any.whl (132 kB)
#      -------------------------------------- 132.5/132.5 kB 3.9 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.3
#   Downloading botocore-1.29.3-py3-none-any.whl (9.8 MB)
#      ---------------------------------------- 9.8/9.8 MB 6.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.6/79.6 kB 4.3 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      -------------------------------------- 140.4/140.4 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\mavic\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from botocore<1.30.0,>=1.29.3->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mavic\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.3->boto3) (1.16.0)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.26.3 botocore-1.29.3 jmespath-1.0.1 s3transfer-0.6.0 urllib3-1.26.12
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: C:\Users\mavic\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import boto3
import pandas as pd
s3 = boto3.client("s3" )
bucket_name = "project-data-maiythack"
s3_object = "power.txt"
obj = s3.get_object(Bucket=bucket_name, Key=s3_object)
df = pd.read_csv(obj['Body'], sep = ";")
# Out:
# C:\Users\mavic\AppData\Local\Temp\ipykernel_60364\1845144713.py:7: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(obj['Body'], sep = ";")

# %%
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# 2075257  26/11/2010  21:01:00               0.934                   0.0
# 2075258  26/11/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# 0        234.840           18.400          0.000          1.000
# 1        233.630           23.000          0.000          1.000
# 2        233.290           23.000          0.000          2.000
# 3        233.740           23.000          0.000          1.000
# 4        235.680           15.800          0.000          1.000
# ...          ...              ...            ...            ...
# 2075254   240.43              4.0            0.0            0.0
# 2075255    240.0              4.0            0.0            0.0
# 2075256   239.82              3.8            0.0            0.0
# 2075257    239.7              3.8            0.0            0.0
# 2075258   239.55              3.8            0.0            0.0
#
#          Sub_metering_3
# 0                  17.0
# 1                  16.0
# 2                  17.0
# 3                  17.0
# 4                  17.0
# ...                 ...
# 2075254             0.0
# 2075255             0.0
# 2075256             0.0
# 2075257             0.0
# 2075258             0.0
#
# [2075259 rows x 9 columns]

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%m/%d/%Y')

df
# Out:
# C:\Users\mavic\AppData\Local\Temp\ipykernel_60364\972350157.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%m/%d/%Y')
#                Date      Time Global_active_power Global_reactive_power  \
# 0        12/16/2006  17:24:00               4.216                 0.418
# 1        12/16/2006  17:25:00               5.360                 0.436
# 2        12/16/2006  17:26:00               5.374                 0.498
# 3        12/16/2006  17:27:00               5.388                 0.502
# 4        12/16/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  11/26/2010  20:58:00               0.946                   0.0
# 2075255  11/26/2010  20:59:00               0.944                   0.0
# 2075256  11/26/2010  21:00:00               0.938                   0.0
# 2075257  11/26/2010  21:01:00               0.934                   0.0
# 2075258  11/26/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# 0        234.840           18.400          0.000          1.000
# 1        233.630           23.000          0.000          1.000
# 2        233.290           23.000          0.000          2.000
# 3        233.740           23.000          0.000          1.000
# 4        235.680           15.800          0.000          1.000
# ...          ...              ...            ...            ...
# 2075254   240.43              4.0            0.0            0.0
# 2075255    240.0              4.0            0.0            0.0
# 2075256   239.82              3.8            0.0            0.0
# 2075257    239.7              3.8            0.0            0.0
# 2075258   239.55              3.8            0.0            0.0
#
#          Sub_metering_3
# 0                  17.0
# 1                  16.0
# 2                  17.0
# 3                  17.0
# 4                  17.0
# ...                 ...
# 2075254             0.0
# 2075255             0.0
# 2075256             0.0
# 2075257             0.0
# 2075258             0.0
#
# [2075259 rows x 9 columns]

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month

# %%
df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  12/16/2006  17:24:00               4.216                 0.418  234.840
# 1  12/16/2006  17:25:00               5.360                 0.436  233.630
# 2  12/16/2006  17:26:00               5.374                 0.498  233.290
# 3  12/16/2006  17:27:00               5.388                 0.502  233.740
# 4  12/16/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3  Month
# 0           18.400          0.000          1.000            17.0     12
# 1           23.000          0.000          1.000            16.0     12
# 2           23.000          0.000          2.000            17.0     12
# 3           23.000          0.000          1.000            17.0     12
# 4           15.800          0.000          1.000            17.0     12

# %%
def find_season(month, hemisphere):
    if hemisphere == 'Southern':
        season_month_south = {
            12:'Summer', 1:'Summer', 2:'Summer',
            3:'Autumn', 4:'Autumn', 5:'Autumn',
            6:'Winter', 7:'Winter', 8:'Winter',
            9:'Spring', 10:'Spring', 11:'Spring'}
        return season_month_south.get(month)
        
    elif hemisphere == 'Northern':
        season_month_north = {
            12:'Winter', 1:'Winter', 2:'Winter',
            3:'Spring', 4:'Spring', 5:'Spring',
            6:'Summer', 7:'Summer', 8:'Summer',
            9:'Autumn', 10:'Autumn', 11:'Autumn'}
        return season_month_north.get(month)
    else:
        print('Invalid selection. Please select a hemisphere and try again')

# %%
season_list = []
hemisphere = 'Northern'
for month in df['Month']:
    season = find_season(month, hemisphere)
    season_list.append(season)
    
df['Season'] = season_list

# %%
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        12/16/2006  17:24:00               4.216                 0.418
# 1        12/16/2006  17:25:00               5.360                 0.436
# 2        12/16/2006  17:26:00               5.374                 0.498
# 3        12/16/2006  17:27:00               5.388                 0.502
# 4        12/16/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  11/26/2010  20:58:00               0.946                   0.0
# 2075255  11/26/2010  20:59:00               0.944                   0.0
# 2075256  11/26/2010  21:00:00               0.938                   0.0
# 2075257  11/26/2010  21:01:00               0.934                   0.0
# 2075258  11/26/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# 0        234.840           18.400          0.000          1.000
# 1        233.630           23.000          0.000          1.000
# 2        233.290           23.000          0.000          2.000
# 3        233.740           23.000          0.000          1.000
# 4        235.680           15.800          0.000          1.000
# ...          ...              ...            ...            ...
# 2075254   240.43              4.0            0.0            0.0
# 2075255    240.0              4.0            0.0            0.0
# 2075256   239.82              3.8            0.0            0.0
# 2075257    239.7              3.8            0.0            0.0
# 2075258   239.55              3.8            0.0            0.0
#
#          Sub_metering_3  Month  Season
# 0                  17.0     12  Winter
# 1                  16.0     12  Winter
# 2                  17.0     12  Winter
# 3                  17.0     12  Winter
# 4                  17.0     12  Winter
# ...                 ...    ...     ...
# 2075254             0.0     11  Autumn
# 2075255             0.0     11  Autumn
# 2075256             0.0     11  Autumn
# 2075257             0.0     11  Autumn
# 2075258             0.0     11  Autumn
#
# [2075259 rows x 11 columns]

# %%
df.drop(['Month'], axis=1, inplace=True)
df
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 0        12/16/2006  17:24:00               4.216                 0.418
# 1        12/16/2006  17:25:00               5.360                 0.436
# 2        12/16/2006  17:26:00               5.374                 0.498
# 3        12/16/2006  17:27:00               5.388                 0.502
# 4        12/16/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  11/26/2010  20:58:00               0.946                   0.0
# 2075255  11/26/2010  20:59:00               0.944                   0.0
# 2075256  11/26/2010  21:00:00               0.938                   0.0
# 2075257  11/26/2010  21:01:00               0.934                   0.0
# 2075258  11/26/2010  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# 0        234.840           18.400          0.000          1.000
# 1        233.630           23.000          0.000          1.000
# 2        233.290           23.000          0.000          2.000
# 3        233.740           23.000          0.000          1.000
# 4        235.680           15.800          0.000          1.000
# ...          ...              ...            ...            ...
# 2075254   240.43              4.0            0.0            0.0
# 2075255    240.0              4.0            0.0            0.0
# 2075256   239.82              3.8            0.0            0.0
# 2075257    239.7              3.8            0.0            0.0
# 2075258   239.55              3.8            0.0            0.0
#
#          Sub_metering_3  Season
# 0                  17.0  Winter
# 1                  16.0  Winter
# 2                  17.0  Winter
# 3                  17.0  Winter
# 4                  17.0  Winter
# ...                 ...     ...
# 2075254             0.0  Autumn
# 2075255             0.0  Autumn
# 2075256             0.0  Autumn
# 2075257             0.0  Autumn
# 2075258             0.0  Autumn
#
# [2075259 rows x 10 columns]

# %%
df[df.isnull().any(axis=1)]
# Out:
#                Date      Time Global_active_power Global_reactive_power  \
# 6839     12/21/2006  11:23:00                   ?                     ?
# 6840     12/21/2006  11:24:00                   ?                     ?
# 19724    12/30/2006  10:08:00                   ?                     ?
# 19725    12/30/2006  10:09:00                   ?                     ?
# 41832    01/14/2007  18:36:00                   ?                     ?
# ...             ...       ...                 ...                   ...
# 1990185  09/28/2010  19:09:00                   ?                     ?
# 1990186  09/28/2010  19:10:00                   ?                     ?
# 1990187  09/28/2010  19:11:00                   ?                     ?
# 1990188  09/28/2010  19:12:00                   ?                     ?
# 2027411  10/24/2010  15:35:00                   ?                     ?
#
#         Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# 6839          ?                ?              ?              ?
# 6840          ?                ?              ?              ?
# 19724         ?                ?              ?              ?
# 19725         ?                ?              ?              ?
# 41832         ?                ?              ?              ?
# ...         ...              ...            ...            ...
# 1990185       ?                ?              ?              ?
# 1990186       ?                ?              ?              ?
# 1990187       ?                ?              ?              ?
# 1990188       ?                ?              ?              ?
# 2027411       ?                ?              ?              ?
#
#          Sub_metering_3  Season
# 6839                NaN  Winter
# 6840                NaN  Winter
# 19724               NaN  Winter
# 19725               NaN  Winter
# 41832               NaN  Winter
# ...                 ...     ...
# 1990185             NaN  Autumn
# 1990186             NaN  Autumn
# 1990187             NaN  Autumn
# 1990188             NaN  Autumn
# 2027411             NaN  Autumn
#
# [25979 rows x 10 columns]

# %%
import numpy as np

# %%
df['Global_active_power'].replace('?', np.nan, inplace = True)
df['Global_reactive_power'].replace('?', np.nan, inplace = True)
df['Voltage'].replace('?', np.nan, inplace = True)
df['Global_intensity'].replace('?', np.nan, inplace = True)
df['Sub_metering_1'].replace('?', np.nan, inplace = True)
df['Sub_metering_2'].replace('?', np.nan, inplace = True)

# %%
df.isnull().sum()
# Out:
# Date                         0
# Time                         0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3           25979
# Season                       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
X = df[['Global_active_power', 'Global_reactive_power', 'Voltage', 'Global_intensity', \
         'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3' ]]
imp_mean.fit(X)
# Out:
# SimpleImputer()

# %%
df2=pd.DataFrame(imp_mean.transform(X), columns=['Global_active_power', 'Global_reactive_power', \
                                                     'Voltage', 'Global_intensity', 'Sub_metering_1', \
                                                     'Sub_metering_2', 'Sub_metering_3'])

# %%
df2
# Out:
#          Global_active_power  Global_reactive_power  Voltage  \
# 0                      4.216                  0.418   234.84
# 1                      5.360                  0.436   233.63
# 2                      5.374                  0.498   233.29
# 3                      5.388                  0.502   233.74
# 4                      3.666                  0.528   235.68
# ...                      ...                    ...      ...
# 2075254                0.946                  0.000   240.43
# 2075255                0.944                  0.000   240.00
# 2075256                0.938                  0.000   239.82
# 2075257                0.934                  0.000   239.70
# 2075258                0.932                  0.000   239.55
#
#          Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0                    18.4             0.0             1.0            17.0
# 1                    23.0             0.0             1.0            16.0
# 2                    23.0             0.0             2.0            17.0
# 3                    23.0             0.0             1.0            17.0
# 4                    15.8             0.0             1.0            17.0
# ...                   ...             ...             ...             ...
# 2075254               4.0             0.0             0.0             0.0
# 2075255               4.0             0.0             0.0             0.0
# 2075256               3.8             0.0             0.0             0.0
# 2075257               3.8             0.0             0.0             0.0
# 2075258               3.8             0.0             0.0             0.0
#
# [2075259 rows x 7 columns]

# %%
df2.isnull().sum()
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64
